# %% [markdown]
# ## Pandas

# %%
import numpy as np
import pandas as pd

# %%
lables=['abshiek','kumar','singh']
list=[10,20,30]
arr=np.array([10,20,30])
des={1:10,2:20,3:30}

# %%
pd.Series(list,index=lables)
# Out:
# abshiek    10
# kumar      20
# singh      30
# dtype: int64

# %%
pd.Series(arr)
# Out:
# 0    10
# 1    20
# 2    30
# dtype: int64

# %%
pd.Series(des)
# Out:
# 1    10
# 2    20
# 3    30
# dtype: int64
